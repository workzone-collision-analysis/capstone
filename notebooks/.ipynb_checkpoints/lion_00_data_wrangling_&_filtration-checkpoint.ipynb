# %% [markdown]
# ## Filtering Attributes in the LION Data Set
# ### This notebook prepares attributes such as roadway type, speed and number of lanes to be joined later to the work zones data to enhace it and prepare it for clustering.

# %%
import numpy
import pandas as pd
import geopandas as gpd
import numpy as np

from fiona.crs import from_epsg
import shapely
from shapely.geometry import Point, Polygon

import re 

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

pylab.rcParams['figure.figsize'] = 30,30
pylab.rcParams['figure.dpi'] = 100
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ### Importing LION - LION Release 20-A was used

# %%
# data can be dowloaded from: https://www1.nyc.gov/site/planning/data-maps/open-data/bytes-archive.page?sorts[year]=0
# select lion from the drop down data menu
# select LION 20A
# the geodatabase was then saved as a shapefile using GIS software
lion_s = gpd.GeoDataFrame.from_file('../data/NYC LION/LION_street/Lion_20A/lion_20A.shp')

# %%
type(lion_s.SegmentID.iloc[0])
# Out:
# str

# %%
lion_s[lion_s.SegmentID.astype(int) == 65969]
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, Street, SAFStreetN, FeatureTyp, SegmentTyp, IncExFlag, RB_Layer, NonPed, TrafDir, TrafSrc, SpecAddr, FaceCode, SeqNum, StreetCode, SAFStreetC, LGC1, LGC2, LGC3, LGC4, LGC5, LGC6, LGC7, LGC8, LGC9, BOE_LGC, SegmentID, SegCount, LocStatus, LZip, RZip, LBoro, RBoro, L_CD, R_CD, LATOMICPOL, RATOMICPOL, LCT2010, LCT2010Suf, RCT2010, RCT2010Suf, LCB2010, LCB2010Suf, RCB2010, RCB2010Suf, LCT2000, LCT2000Suf, RCT2000, RCT2000Suf, LCB2000, LCB2000Suf, RCB2000, RCB2000Suf, LCT1990, LCT1990Suf, RCT1990, RCT1990Suf, LAssmDist, LElectDist, RAssmDist, RElectDist, SplitElect, LSchlDist, RSchlDist, SplitSchl, LSubSect, RSubSect, SanDistInd, MapFrom, MapTo, BoroBndry, MH_RI_Flag, XFrom, YFrom, XTo, YTo, ArcCenterX, ArcCenterY, CurveFlag, Radius, NodeIDFrom, NodeIDTo, NodeLevelF, NodeLevelT, ConParity, Twisted, RW_TYPE, PhysicalID, GenericID, NYPDID, FDNYID, LBlockFace, RBlockFace, LegacyID, Status, StreetWidt, StreetWi_1, StreetWi_2, BikeLane, BIKE_TRAFD, ACTIVE_FLA, ...]
# Index: []
#
# [0 rows x 122 columns]

# %%
lion_s.head()
# Out:
#    OBJECTID            Street          SAFStreetN FeatureTyp SegmentTyp  \
# 0       1.0   EAST 168 STREET                None          0          U
# 1       2.0   WEST 192 STREET                None          0          U
# 2       3.0      UNION AVENUE                None          0          U
# 3       4.0      UNION AVENUE  BEHAGEN PLAYGROUND          0          U
# 4       5.0  DELAFIELD AVENUE                None          6          U
#
#   IncExFlag RB_Layer NonPed TrafDir TrafSrc SpecAddr FaceCode SeqNum  \
# 0      None        B   None       T     DOT     None     2510  03070
# 1      None        B   None       A     DOT     None     7984  00040
# 2      None        B   None       W     DOT     None     7280  00130
# 3      None        B   None       W     DOT        N     7280  00130
# 4      None        B   None       T     DOT     None     1876  01020
#
#   StreetCode SAFStreetC LGC1  LGC2  LGC3  LGC4  LGC5  LGC6  LGC7  LGC8  LGC9  \
# 0     226700       None   01  None  None  None  None  None  None  None  None
# 1     274810       None   01  None  None  None  None  None  None  None  None
# 2     270420       None   01  None  None  None  None  None  None  None  None
# 3     270420     212795   01  None  None  None  None  None  None  None  None
# 4     224120       None   01  None  None  None  None  None  None  None  None
#
#   BOE_LGC SegmentID SegCount LocStatus   LZip   RZip  LBoro  RBoro L_CD R_CD  \
# 0       1   0078126        1         X  10456  10456    2.0    2.0  203  203
# 1       1   0079796        1      None  10468  10468    2.0    2.0  207  207
# 2       1   0077356        2         X  10459  10459    2.0    2.0  203  203
# 3       1   0077356        2         X  10459  10459    2.0    2.0  203  203
# 4       1   0073490        1      None  10471  10471    2.0    2.0  208  208
#
#   LATOMICPOL RATOMICPOL LCT2010 LCT2010Suf RCT2010 RCT2010Suf LCB2010  \
# 0        402        101     149       None     185       None    3001
# 1        302        104     265       None     265       None    2000
# 2        402        401     135       None     131       None    2000
# 3        402        401     135       None     131       None    2000
# 4        119        123     335       None     335       None    1004
#
#   LCB2010Suf RCB2010 RCB2010Suf LCT2000 LCT2000Suf RCT2000 RCT2000Suf LCB2000  \
# 0       None    2000       None     149       None     137       None    4000
# 1       None    1004       None     265       None     265       None    3001
# 2       None    3006       None     135       None     131       None    4000
# 3       None    3006       None     135       None     131       None    4000
# 4       None    1008       None     333       None     333       None    1009
#
#   LCB2000Suf  ...   YFrom      XTo     YTo ArcCenterX ArcCenterY CurveFlag  \
# 0       None  ...  241812  1011265  241555          0          0      None
# 1       None  ...  255024  1011335  255164          0          0      None
# 2       None  ...  239640  1011786  240230          0          0      None
# 3       None  ...  239640  1011786  240230          0          0      None
# 4       None  ...  264857  1009974  265527          0          0      None
#
#   Radius NodeIDFrom NodeIDTo NodeLevelF NodeLevelT ConParity Twisted RW_TYPE  \
# 0      0    0047740  9045677          M          M      None    None       1
# 1      0    0048679  0048678          M          M      None    None       1
# 2      0    0047288  0047822          M          M      None    None       1
# 3      0    0047288  0047822          M          M      None    None       1
# 4      0    0045034  0045038          M          M      None    None       1
#
#   PhysicalID GenericID NYPDID FDNYID  LBlockFace  RBlockFace LegacyID  Status  \
# 0    35231.0   30694.0   None   None  1422600653  1422602017  0078126       2
# 1    35248.0   30711.0   None   None  1522607129  1522607721  0079796       2
# 2    35252.0   30715.0   None   None  1422603726  1422604132  0077356       2
# 3    35252.0   30715.0   None   None  1422603726  1422604132  0077356       2
# 4    35275.0   30738.0   None   None  1522605283  1522610703  0073490       2
#
#    StreetWidt  StreetWi_1  StreetWi_2  BikeLane  BIKE_TRAFD ACTIVE_FLA  \
# 0        34.0        34.0        None      None        None       None
# 1        30.0        30.0        None      None        None       None
# 2        34.0        34.0        None      None        None       None
# 3        34.0        34.0        None      None        None       None
# 4        30.0        30.0        None      None        None       None
#
#    POSTED_SPE Snow_Prior Number_Tra Number_Par Number_Tot Carto_Disp   FCC  \
# 0          25          S          2          2          4       None  None
# 1          25          S          1          2          3       None  None
# 2          25          S          1          2          3       None  None
# 3          25          S          1          2          3       None  None
# 4        None          V          1          2          3       None  None
#
#   ROW_Type  LLo_Hyphen  LHi_Hyphen RLo_Hyphen RHi_Hyphen FromLeft ToLeft  \
# 0     None         599         699        596        716      599    699
# 1     None          58          98         63         99       58     98
# 2     None        1017        1079       1016       1084     1017   1079
# 3     None        None        None       None       None        0      0
# 4     None        4601        4645       4600       4664     4601   4645
#
#   FromRight ToRight          Join_ID  L_PD_Servi R_PD_Servi TRUCK_ROUT  \
# 0       596     716    2251001000000        None       None       None
# 1        63      99    2798401000000        None       None       None
# 2      1016    1084    2728001000000        None       None       None
# 3         0       0  21279501000000N        None       None       None
# 4      4600    4664    2187601000000        None       None       None
#
#    SHAPE_Leng                                           geometry
# 0  396.030947  LINESTRING (-73.90347 40.83035, -73.90238 40.8...
# 1  279.360514  LINESTRING (-73.90120 40.86661, -73.90207 40.8...
# 2  618.327133  LINESTRING (-73.90118 40.82439, -73.90051 40.8...
# 3  618.327133  LINESTRING (-73.90118 40.82439, -73.90051 40.8...
# 4  670.281037  LINESTRING (-73.90696 40.89361, -73.90696 40.8...
#
# [5 rows x 122 columns]

# %%
lion_s.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 228248 entries, 0 to 228247
# Columns: 122 entries, OBJECTID to geometry
# dtypes: float64(8), geometry(1), int64(11), object(102)
# memory usage: 212.5+ MB

# %%
lion_s.shape
# Out:
# (228248, 122)

# %% [markdown]
# ### Data Cleaning

# %%
print("lion_s Shape: {}\n\nNull Values in each column\n".format(lion_s.shape))
for col in lion_s.columns:
    print(col, '\t\t', lion_s[col].isnull().sum())
# Out:
# lion_s Shape: (228248, 122)
#
# Null Values in each column
#
# OBJECTID 		 0
# Street 		 0
# SAFStreetN 		 211093
# FeatureTyp 		 0
# SegmentTyp 		 0
# IncExFlag 		 223389
# RB_Layer 		 0
# NonPed 		 196061
# TrafDir 		 34693
# TrafSrc 		 44543
# SpecAddr 		 211093
# FaceCode 		 0
# SeqNum 		 0
# StreetCode 		 0
# SAFStreetC 		 211093
# LGC1 		 0
# LGC2 		 162139
# LGC3 		 216197
# LGC4 		 222435
# LGC5 		 227751
# LGC6 		 227915
# LGC7 		 228243
# LGC8 		 228245
# LGC9 		 228248
# BOE_LGC 		 0
# SegmentID 		 0
# SegCount 		 0
# LocStatus 		 174675
# LZip 		 9536
# RZip 		 9036
# LBoro 		 1408
# RBoro 		 883
# L_CD 		 1409
# R_CD 		 884
# LATOMICPOL 		 1409
# RATOMICPOL 		 884
# LCT2010 		 1409
# LCT2010Suf 		 177011
# RCT2010 		 884
# RCT2010Suf 		 176871
# LCB2010 		 1409
# LCB2010Suf 		 228248
# RCB2010 		 884
# RCB2010Suf 		 228248
# LCT2000 		 1409
# LCT2000Suf 		 183749
# RCT2000 		 884
# RCT2000Suf 		 183745
# LCB2000 		 1409
# LCB2000Suf 		 205444
# RCB2000 		 884
# RCB2000Suf 		 205520
# LCT1990 		 1409
# LCT1990Suf 		 180756
# RCT1990 		 884
# RCT1990Suf 		 180630
# LAssmDist 		 1429
# LElectDist 		 1429
# RAssmDist 		 885
# RElectDist 		 885
# SplitElect 		 228119
# LSchlDist 		 10143
# RSchlDist 		 8370
# SplitSchl 		 228248
# LSubSect 		 63074
# RSubSect 		 63222
# SanDistInd 		 225846
# MapFrom 		 0
# MapTo 		 0
# BoroBndry 		 225957
# MH_RI_Flag 		 227541
# XFrom 		 0
# YFrom 		 0
# XTo 		 0
# YTo 		 0
# ArcCenterX 		 0
# ArcCenterY 		 0
# CurveFlag 		 196037
# Radius 		 0
# NodeIDFrom 		 0
# NodeIDTo 		 0
# NodeLevelF 		 0
# NodeLevelT 		 0
# ConParity 		 225175
# Twisted 		 227677
# RW_TYPE 		 33382
# PhysicalID 		 51011
# GenericID 		 66196
# NYPDID 		 217516
# FDNYID 		 228248
# LBlockFace 		 68281
# RBlockFace 		 68287
# LegacyID 		 0
# Status 		 33382
# StreetWidt 		 60907
# StreetWi_1 		 61919
# StreetWi_2 		 228248
# BikeLane 		 207602
# BIKE_TRAFD 		 207661
# ACTIVE_FLA 		 222412
# POSTED_SPE 		 80431
# Snow_Prior 		 48218
# Number_Tra 		 61762
# Number_Par 		 114766
# Number_Tot 		 61857
# Carto_Disp 		 198136
# FCC 		 228248
# ROW_Type 		 219917
# LLo_Hyphen 		 126716
# LHi_Hyphen 		 126729
# RLo_Hyphen 		 126061
# RHi_Hyphen 		 126075
# FromLeft 		 0
# ToLeft 		 0
# FromRight 		 0
# ToRight 		 0
# Join_ID 		 0
# L_PD_Servi 		 223684
# R_PD_Servi 		 223507
# TRUCK_ROUT 		 191813
# SHAPE_Leng 		 0
# geometry 		 0

# %%
# define a function that puts underscore before capital letters and convert to lower case
def convert(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

# removing present underscores in some columns
tmp = lion_s.columns.str.replace('_', '')

# mapping the convert function on column names
tmp = list(map(convert, lion_s.columns))

tmp = [name.replace('__', '_') for name in tmp]
tmp = [name.replace('saf_street_n', 'saf_street_name') for name in tmp]
tmp = [name.replace('saf_street_c', 'saf_street_code') for name in tmp]

for name in tmp:
    print(name)
# Out:
# objectid
# street
# saf_street_name
# feature_typ
# segment_typ
# inc_ex_flag
# rb_layer
# non_ped
# traf_dir
# traf_src
# spec_addr
# face_code
# seq_num
# street_code
# saf_street_code
# lgc1
# lgc2
# lgc3
# lgc4
# lgc5
# lgc6
# lgc7
# lgc8
# lgc9
# boe_lgc
# segment_id
# seg_count
# loc_status
# l_zip
# r_zip
# l_boro
# r_boro
# l_cd
# r_cd
# latomicpol
# ratomicpol
# lct2010
# lct2010_suf
# rct2010
# rct2010_suf
# lcb2010
# lcb2010_suf
# rcb2010
# rcb2010_suf
# lct2000
# lct2000_suf
# rct2000
# rct2000_suf
# lcb2000
# lcb2000_suf
# rcb2000
# rcb2000_suf
# lct1990
# lct1990_suf
# rct1990
# rct1990_suf
# l_assm_dist
# l_elect_dist
# r_assm_dist
# r_elect_dist
# split_elect
# l_schl_dist
# r_schl_dist
# split_schl
# l_sub_sect
# r_sub_sect
# san_dist_ind
# map_from
# map_to
# boro_bndry
# mh_ri_flag
# x_from
# y_from
# x_to
# y_to
# arc_center_x
# arc_center_y
# curve_flag
# radius
# node_id_from
# node_id_to
# node_level_f
# node_level_t
# con_parity
# twisted
# rw_type
# physical_id
# generic_id
# nypdid
# fdnyid
# l_block_face
# r_block_face
# legacy_id
# status
# street_widt
# street_wi_1
# street_wi_2
# bike_lane
# bike_trafd
# active_fla
# posted_spe
# snow_prior
# number_tra
# number_par
# number_tot
# carto_disp
# fcc
# row_type
# l_lo_hyphen
# l_hi_hyphen
# r_lo_hyphen
# r_hi_hyphen
# from_left
# to_left
# from_right
# to_right
# join_id
# l_pd_servi
# r_pd_servi
# truck_rout
# shape_leng
# geometry

# %%
lion_s.columns = tmp

# %%
lion_s.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# lion_s.to_file('../data/cleaned_data/lion_segments.shp')

# %% [markdown]
# ### Filtering out attributes that we do not need for our analysis.
# ### This was based on recommendations from previous work our sponsor has done

# %%
lion_s.feature_typ.value_counts().sort_index()
# Out:
# 0    178187
# 1      8331
# 2      9237
# 3     11164
# 5       286
# 6      9381
# 7      3008
# 8      1642
# 9      1025
# A      4005
# C        50
# F       934
# W       998
# Name: feature_typ, dtype: int64

# %%
# selecting feature type 0: street other than vehicle only street & 6: Private Street
feature_type = ['0', '6']
lion_f = lion_s[lion_s.feature_typ.isin(feature_type)]
print('before:', lion_s.shape, '\nafter:', lion_f.shape, '\nlost:', lion_s.shape[0] - lion_f.shape[0])
# Out:
# before: (228248, 122)
# after: (187568, 122)
# lost: 40680

# %%
lion_s.segment_typ.value_counts().sort_index()
# Out:
# B       596
# C       836
# E      5554
# F      3356
# G     12972
# R     27845
# S       976
# T      1851
# U    174262
# Name: segment_typ, dtype: int64

# %%
# selecting segment type
# B: both (generic and roadbed (odd number of roadways))
# C: connector (connect adjacent roadbeds of a divided street)
# E: entrance/exit ramp (connects a highway to a different street or highway)
# R: roadbed segment (depicts physically separated carriageway segments of a particular street)
# T: terminator (a divided section of a street terminates, but the street itself continues)
# U: undivided street (all other LION segments that do not fall into any of the above categories)
# S: suppressed (undivided segment to be suppressed in a generic view of LION)
segment_type = ['B', 'C', 'E', 'R', 'T', 'U', 'S']
lion_g = lion_f[lion_f.segment_typ.isin(segment_type)]
print('before:', lion_f.shape, '\nafter:', lion_g.shape, '\nlost:', lion_f.shape[0] - lion_g.shape[0])
# Out:
# before: (187568, 122)
# after: (171319, 122)
# lost: 16249

# %%
lion_s.rw_type.value_counts().sort_index()
# Out:
# 1     152393
# 10      4007
# 12      4135
# 13       552
# 14       934
# 2      14354
# 3       3253
# 4        359
# 5        198
# 6       7404
# 7        275
# 8       1165
# 9       5837
# Name: rw_type, dtype: int64

# %%
# selecting roadway types
# 1: street
# 2: Highway
# 3: Bridge
# 4: Tunnel
# 8: Driveway
# 9: Ramp
# 10: Alley
# 11: Unknown
# 13: U-turn

roadway_type = ['1', '2', '3', '4', '8', '9', '10', '11', '13']
lion_r = lion_g[lion_g.rw_type.isin(roadway_type)]
print('before:', lion_g.shape, '\nafter:', lion_r.shape, '\nlost:', lion_g.shape[0] - lion_r.shape[0])
# Out:
# before: (171319, 122)
# after: (164386, 122)
# lost: 6933

# %%
lion_r.rw_type.value_counts().sort_index()
# Out:
# 1     143935
# 10         2
# 13       552
# 2       9865
# 3       2877
# 4        261
# 8       1131
# 9       5763
# Name: rw_type, dtype: int64

# %%
lion_r.rw_type.isnull().sum()
# Out:
# 0

# %%
lion_s.traf_dir.value_counts().sort_index()
# Out:
# A    40288
# P    11529
# T    96655
# W    45083
# Name: traf_dir, dtype: int64

# %%
lion_s.traf_dir.unique()
# Out:
# array(['T', 'A', 'W', 'P', None], dtype=object)

# %%
len(lion_s.traf_dir.isnull())
# Out:
# 228248

# %%
# selecting traffic
# 'W': With: One-way street, traffic flows with the segment's directionality
# 'A': Against: One-way street, traffic flows from against the segment's directionality
# 'T': Two-Way: Traffic flows in both directions

traffic_direction = ['W', 'A', 'T']
lion_t = lion_r[lion_r.traf_dir.isin(traffic_direction)]
print('before:', lion_r.shape, '\nafter:', lion_t.shape, '\nlost:', lion_r.shape[0] - lion_t.shape[0])
# Out:
# before: (164386, 122)
# after: (161942, 122)
# lost: 2444

# %%
print('rows lost from all the filtration:', lion_s.shape[0] - lion_t.shape[0])
# Out:
# rows lost from all the filtration: 66306

# %%
print('number of duplicate segment ids: ', lion_t.shape[0] - lion_t.drop_duplicates(subset='segment_id').shape[0])
# Out:
# number of duplicate segment ids:  17474

# %%
lion_t.saf_street_name.unique()
# Out:
# array([None, 'BEHAGEN PLAYGROUND', 'DREW PLAYGROUND', ...,
#        'DEBBIE STREET', 'NORBERT LEESEBERG PERENNIAL GDN',
#        'GRANITEVILLE SWAMP PARK'], dtype=object)

# %%
# rows that have a special address place name
lion_t[~lion_t.saf_street_name.isnull()].shape
# Out:
# (15913, 122)

# %%
# selecting rows that do not have a special address place name
lion_d = lion_t[lion_t.saf_street_name.isnull()]
print('before:', lion_t.shape, '\nafter:', lion_d.shape, '\nlost:', lion_t.shape[0] - lion_d.shape[0])
# Out:
# before: (161942, 122)
# after: (146029, 122)
# lost: 15913

# %%
print('number of duplicate segment ids: ', lion_d.shape[0] - lion_d.drop_duplicates(subset='segment_id').shape[0])
# Out:
# number of duplicate segment ids:  1561

# %%
# dropping identical line segments i.e. having the same 2d position and elevation 
lion_i = lion_d.drop_duplicates(subset=['x_from', 'y_from', 'x_to', 'y_to', 'node_level_f', 'node_level_t'])
print('before:', lion_d.shape, '\nafter:', lion_i.shape, '\nlost:', lion_d.shape[0] - lion_i.shape[0])
# Out:
# before: (146029, 122)
# after: (144441, 122)
# lost: 1588

# %%
print('number of duplicate segment ids: ', lion_i[lion_i.duplicated(subset='segment_id')].shape[0])
# Out:
# number of duplicate segment ids:  14

# %%
lion_i = lion_i.drop_duplicates(subset='segment_id')
lion_i.shape
# Out:
# (144427, 122)

# %%
print('number of duplicate segment ids: ', lion_i[lion_i.duplicated(subset='segment_id')].shape[0])
# Out:
# number of duplicate segment ids:  0

# %%
# lion_i.to_file('../data/cleaned_data/lion_filtered.geojson', driver='GeoJSON')

# %%
lion_i.to_file('../data/cleaned_data/lion_filtered.shp')

# %%
# lion_i.to_file('../data/cleaned_data/lion_filtered.csv', index=False)

# %%
# lion_i.plot()

# %%
# subsetting interesting columns
lion_sub = lion_i[['segment_id', 'feature_typ', 'segment_typ', 'rw_type', 'traf_dir', 'loc_status', 'curve_flag', 'radius', 'street_widt', 'street_wi_1', 'bike_lane', 'bike_trafd', 'number_tra', 'number_par', 'number_tot', 'posted_spe', 'snow_prior', 'geometry']]
lion_sub.head(3)
# Out:
#   segment_id feature_typ segment_typ rw_type traf_dir loc_status curve_flag  \
# 0    0078126           0           U       1        T          X       None
# 1    0079796           0           U       1        A       None       None
# 2    0077356           0           U       1        W          X       None
#
#    radius  street_widt  street_wi_1 bike_lane bike_trafd number_tra  \
# 0       0         34.0         34.0      None       None          2
# 1       0         30.0         30.0      None       None          1
# 2       0         34.0         34.0      None       None          1
#
#   number_par number_tot posted_spe snow_prior  \
# 0          2          4         25          S
# 1          2          3         25          S
# 2          2          3         25          S
#
#                                             geometry
# 0  LINESTRING (-73.90347 40.83035, -73.90238 40.8...
# 1  LINESTRING (-73.90120 40.86661, -73.90207 40.8...
# 2  LINESTRING (-73.90118 40.82439, -73.90051 40.8...

# %%
# renaming columns
lion_sub.columns = ['segment_id', 'feat_typ', 'seg_typ', 'rw_type', 'traf_dir', 'loc_status', 'curve_flag', 'radius', 'st_wid_min', 'st_wid_max', 'bike_lane', 'b_traf_dir', 'n_trvl_ln', 'n_park_ln', 'n_total_ln', 'posted_spd', 'snow_prio', 'geometry']
lion_sub.head(2)
# Out:
#   segment_id feat_typ seg_typ rw_type traf_dir loc_status curve_flag  radius  \
# 0    0078126        0       U       1        T          X       None       0
# 1    0079796        0       U       1        A       None       None       0
#
#    st_wid_min  st_wid_max bike_lane b_traf_dir n_trvl_ln n_park_ln n_total_ln  \
# 0        34.0        34.0      None       None         2         2          4
# 1        30.0        30.0      None       None         1         2          3
#
#   posted_spd snow_prio                                           geometry
# 0         25         S  LINESTRING (-73.90347 40.83035, -73.90238 40.8...
# 1         25         S  LINESTRING (-73.90120 40.86661, -73.90207 40.8...

# %%
# lion_sub.to_file('../data/cleaned_data/lion_filtered_sub.csv', index=False)

# %%
lion_sub.to_file('../data/cleaned_data/lion_filtered_sub.shp')

# %%
lion_s[lion_s['segment_id'] == '9017006']
# Out:
#         objectid          street saf_street_name feature_typ segment_typ  \
# 105192  105193.0  EAST 25 STREET            None           W           U
#
#        inc_ex_flag rb_layer non_ped traf_dir traf_src spec_addr face_code  \
# 105192        None        B    None        P      DOT      None      1470
#
#        seq_num street_code saf_street_code lgc1 lgc2  lgc3  lgc4  lgc5  lgc6  \
# 105192   00038      117490            None   01   02  None  None  None  None
#
#         lgc7  lgc8  lgc9 boe_lgc segment_id seg_count loc_status  l_zip  \
# 105192  None  None  None       1    9017006         1       None  10010
#
#         r_zip  l_boro  r_boro l_cd r_cd latomicpol ratomicpol lct2010  \
# 105192  10010     1.0     1.0  106  106        103        104      68
#
#        lct2010_suf rct2010 rct2010_suf lcb2010 lcb2010_suf rcb2010  \
# 105192        None      68        None    5000        None    5001
#
#        rcb2010_suf lct2000 lct2000_suf rct2000 rct2000_suf lcb2000  \
# 105192        None      68        None      68        None    1003
#
#        lcb2000_suf  ...  y_from    x_to    y_to arc_center_x arc_center_y  \
# 105192        None  ...  209035  989179  208921            0            0
#
#        curve_flag radius node_id_from node_id_to node_level_f node_level_t  \
# 105192       None      0      9011613    0021001            M            M
#
#        con_parity twisted rw_type physical_id generic_id nypdid fdnyid  \
# 105192       None    None       1     16775.0    14191.0   None   None
#
#        l_block_face r_block_face legacy_id  status  street_widt  street_wi_1  \
# 105192         None         None   0033183       2          NaN          NaN
#
#         street_wi_2  bike_lane  bike_trafd active_fla  posted_spe snow_prior  \
# 105192         None       None        None       None        None          V
#
#        number_tra number_par number_tot carto_disp   fcc row_type  \
# 105192       None       None       None       None  None     None
#
#         l_lo_hyphen  l_hi_hyphen r_lo_hyphen r_hi_hyphen from_left to_left  \
# 105192          155          199         158         198       155     199
#
#        from_right to_right        join_id  l_pd_servi r_pd_servi truck_rout  \
# 105192        158      198  1147001020000        None       None       None
#
#         shape_leng                                           geometry
# 105192  235.140348  LINESTRING (-73.98295 40.74043, -73.98221 40.7...
#
# [1 rows x 122 columns]

# %%
lion_sub.shape
# Out:
# (144427, 18)

# %%
lion_sub[lion_sub.duplicated(subset='segment_id')]
# Out:
# Empty GeoDataFrame
# Columns: [segment_id, feat_typ, seg_typ, rw_type, traf_dir, loc_status, curve_flag, radius, st_wid_min, st_wid_max, bike_lane, b_traf_dir, n_trvl_ln, n_park_ln, n_total_ln, posted_spd, snow_prio, geometry]
# Index: []
