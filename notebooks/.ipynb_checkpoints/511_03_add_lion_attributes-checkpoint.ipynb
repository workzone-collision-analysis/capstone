# %% [markdown]
# ## Merging 511 events and Lion dataset

# %% [markdown]
# This notebook is for adding lion street characterisctis on each 511 events.

# %% [markdown]
# Lion Usable attributes:
#
# 1. Segment type (undivided street, both could mean a median lane maybe, ramp)
#
# 2. Roadway type
#
# 3. Traffic direction
#
# 4. Loc status
#
# 5. Curve flag
#
# 6. Radius?
#
# 7. Min st width
#
# 8. Max st width
#
# 9. Bike lane (0,1)
#
# 10. Bike lane
#
# 11. number of travel lanes
#
# 12. number of park lanes
#
# 13. number of total lanes
#
# 14. Posted Speed
#
# 15. Snow removal priority

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
# make sure that you run the 'lion_00_data_wrangling_&_filtration' notebook to get the 'lion_filtered.shp'
# import the lion segments
gdf_lion = gpd.read_file('../data/cleaned_data/lion_filtered/lion_filtered.shp')

# %%
gdf_lion.columns.tolist()
# Out:
# ['objectid',
#  'street',
#  'saf_street',
#  'feature_ty',
#  'segment_ty',
#  'inc_ex_fla',
#  'rb_layer',
#  'non_ped',
#  'traf_dir',
#  'traf_src',
#  'spec_addr',
#  'face_code',
#  'seq_num',
#  'street_cod',
#  'saf_stre_1',
#  'lgc1',
#  'lgc2',
#  'lgc3',
#  'lgc4',
#  'lgc5',
#  'lgc6',
#  'lgc7',
#  'lgc8',
#  'lgc9',
#  'boe_lgc',
#  'segment_id',
#  'seg_count',
#  'loc_status',
#  'l_zip',
#  'r_zip',
#  'l_boro',
#  'r_boro',
#  'l_cd',
#  'r_cd',
#  'latomicpol',
#  'ratomicpol',
#  'lct2010',
#  'lct2010_su',
#  'rct2010',
#  'rct2010_su',
#  'lcb2010',
#  'lcb2010_su',
#  'rcb2010',
#  'rcb2010_su',
#  'lct2000',
#  'lct2000_su',
#  'rct2000',
#  'rct2000_su',
#  'lcb2000',
#  'lcb2000_su',
#  'rcb2000',
#  'rcb2000_su',
#  'lct1990',
#  'lct1990_su',
#  'rct1990',
#  'rct1990_su',
#  'l_assm_dis',
#  'l_elect_di',
#  'r_assm_dis',
#  'r_elect_di',
#  'split_elec',
#  'l_schl_dis',
#  'r_schl_dis',
#  'split_schl',
#  'l_sub_sect',
#  'r_sub_sect',
#  'san_dist_i',
#  'map_from',
#  'map_to',
#  'boro_bndry',
#  'mh_ri_flag',
#  'x_from',
#  'y_from',
#  'x_to',
#  'y_to',
#  'arc_center',
#  'arc_cent_1',
#  'curve_flag',
#  'radius',
#  'node_id_fr',
#  'node_id_to',
#  'node_level',
#  'node_lev_1',
#  'con_parity',
#  'twisted',
#  'rw_type',
#  'physical_i',
#  'generic_id',
#  'nypdid',
#  'fdnyid',
#  'l_block_fa',
#  'r_block_fa',
#  'legacy_id',
#  'status',
#  'street_wid',
#  'street_wi_',
#  'street_w_1',
#  'bike_lane',
#  'bike_trafd',
#  'active_fla',
#  'posted_spe',
#  'snow_prior',
#  'number_tra',
#  'number_par',
#  'number_tot',
#  'carto_disp',
#  'fcc',
#  'row_type',
#  'l_lo_hyphe',
#  'l_hi_hyphe',
#  'r_lo_hyphe',
#  'r_hi_hyphe',
#  'from_left',
#  'to_left',
#  'from_right',
#  'to_right',
#  'join_id',
#  'l_pd_servi',
#  'r_pd_servi',
#  'truck_rout',
#  'shape_leng',
#  'geometry']

# %%
# make sure that you run the '511_02_counting_crash' notebook to get the '511_crashcount_0629.csv'
# import 511 events with crash counts
df_511_crash = pd.read_csv('../data/cleaned_data/511_crashcount_0629.csv')

# %%
# Extract useful columns as a different geodataframe
gdf_lion_simplified = gdf_lion[['segment_id',
                                'segment_ty',
                                'rw_type',
                                'traf_dir',
                                'loc_status',
                                'curve_flag',
                                'radius',
                                'street_wid',
                                'bike_lane',
                                'bike_trafd',
                                'number_tra',
                                'number_par',
                                'number_tot',
                                'posted_spe',
                                'snow_prior']]

# %%
# correct column names
gdf_lion_simplified = gdf_lion_simplified.rename(columns={'segment_ty':'segment_type',
                                                          'rw_type': 'roadway_type',
                                                          'traf_dir':'traffic_direction',
                                                          'bike_trafd':'bike_traffic_direction',
                                                          'number_par':'number_park',
                                                          'number_tra':'number_travel',
                                                          'number_tot':'number_total',
                                                          'posted_spe': 'posted_speed',
                                                          'street_wid': 'street_width'})

# %%
# change a type of segment id from string to int
gdf_lion_simplified['segment_id'] = gdf_lion_simplified['segment_id'].astype(int)

# %%
# import lion, shst lookup table
df_lion_shst_lookup = pd.read_csv('../data/cleaned_data/shst_lion_lookuptable.csv')

# %%
df_lion_shst_lookup.head()
# Out:
#                      shstGeometryId  pp_objectid  pp_segment_id
# 0  a5c5f21851e81c507b141aecc2c6235e            1          78126
# 1  8486febe149b7fbeba3b499188f5bc2a            2          79796
# 2  300959ea23f9820fbe692a4a89a67396            3          77356
# 3  d39717c7db5c64930d589e45414b839e            5          73490
# 4  8af91954050b3b92b77dccfa206cfc19            6         174633

# %%
def get_lion_segment_id(geometryid):
    '''
    This function returns list of the lion segments id from shst geometry id.
    
    ------
    Input :
        geometryid (string): Sharedstreet geometryid    
    
    -----
    Output :
        list_segment_id (list): list of lion segment id that matched to sharedstreet segment
    
    '''
    list_segment_id = df_lion_shst_lookup.loc[df_lion_shst_lookup['shstGeometryId']==geometryid]['pp_segment_id'].tolist()
    return list_segment_id

# %%
# get list of lion segment ids from shstgeometry ID 
df_511_crash['segment_id_list'] = df_511_crash['geometryId'].apply(lambda x:get_lion_segment_id(x))

# %%
df_511_crash['segment_count'] = df_511_crash['segment_id_list'].apply(lambda x:len(x))

# %%
# filter out 511 events that isn't matched with any lion segment 
df_511_crash = df_511_crash.drop(df_511_crash.loc[df_511_crash['segment_count']==0].index)

# %%
# drop unnecessary columns
df_511_crash = df_511_crash.drop('segment_count', axis=1)

# %%
df_511_crash.shape
# Out:
# (25358, 26)

# %%
df_511_crash.head()
# Out:
#    event_id           Event Type                          Organizati  \
# 0         0         construction  Port Authority New York/New Jersey
# 1         1         construction  Port Authority New York/New Jersey
# 2         4  bridge construction  Port Authority New York/New Jersey
# 3         6         construction  Port Authority New York/New Jersey
# 4        19         construction  Port Authority New York/New Jersey
#
#                  Facility N  Direction       City    County State  \
# 0  George Washington Bridge  Westbound  Manhattan  New York    NY
# 1  George Washington Bridge  Westbound  Manhattan  New York    NY
# 2  George Washington Bridge  Westbound  Manhattan  New York    NY
# 3  George Washington Bridge  Westbound  Manhattan  New York    NY
# 4  George Washington Bridge  Westbound  Manhattan  New York    NY
#
#             Create Tim           Close Time  ...  \
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...
# 1  2019-09-30T23:33:00  2019-10-05T10:01:00  ...
# 2  2019-09-30T22:35:00  2019-10-04T14:47:00  ...
# 3  2019-09-30T21:49:00  2019-10-06T10:17:00  ...
# 4  2019-09-27T08:08:00  2019-09-27T13:31:00  ...
#
#                                        geometry  \
# 0   POINT (-73.9452906062501 40.85016678170324)
# 1   POINT (-73.9452906062501 40.85016678170324)
# 2  POINT (-73.95270838629047 40.85161714904007)
# 3   POINT (-73.9452906062501 40.85016678170324)
# 4   POINT (-73.9452906062501 40.85016678170324)
#
#                                buffer_geometry_900ft  \
# 0  POLYGON ((992680.4460278568 251695.5213804595,...
# 1  POLYGON ((992680.4460278568 251695.5213804595,...
# 2  POLYGON ((992680.4460278568 251695.5213804595,...
# 3  POLYGON ((992680.4460278568 251695.5213804595,...
# 4  POLYGON ((992680.4460278568 251695.5213804595,...
#
#                               buffer_geometry_1800ft  \
# 0  POLYGON ((993278.5442073554 252368.045084052, ...
# 1  POLYGON ((993278.5442073554 252368.045084052, ...
# 2  POLYGON ((993278.5442073554 252368.045084052, ...
# 3  POLYGON ((993278.5442073554 252368.045084052, ...
# 4  POLYGON ((993278.5442073554 252368.045084052, ...
#
#                               buffer_geometry_2700ft  \
# 0  POLYGON ((993495.2826707244 247638.1129178417,...
# 1  POLYGON ((993495.2826707244 247638.1129178417,...
# 2  POLYGON ((993495.2826707244 247638.1129178417,...
# 3  POLYGON ((993495.2826707244 247638.1129178417,...
# 4  POLYGON ((993495.2826707244 247638.1129178417,...
#
#                               buffer_geometry_3600ft crash_list_900ft  \
# 0  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
# 1  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
# 2  POLYGON ((993323.9419628344 246752.2208376681,...               []
# 3  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
# 4  POLYGON ((993323.9419628344 246752.2208376681,...               []
#
#              crash_list_1800ft  \
# 0  [4218698, 4220414, 4220401]
# 1           [4218698, 4220401]
# 2                    [4220401]
# 3  [4218698, 4220414, 4220401]
# 4                           []
#
#                                    crash_list_2700ft  \
# 0  [4216810, 4218698, 4220414, 4220401, 4218408, ...
# 1      [4216810, 4218698, 4220401, 4217050, 4216342]
# 2               [4220401, 4217050, 4216342, 4216810]
# 3  [4216810, 4218698, 4220414, 4220401, 4218408, ...
# 4                                          [4213587]
#
#                                    crash_list_3600ft  \
# 0  [4218684, 4218686, 4218688, 4218046, 4216810, ...
# 1  [4218684, 4218686, 4218688, 4218046, 4216810, ...
# 2  [4220401, 4215847, 4217050, 4216342, 4218398, ...
# 3  [4218684, 4218686, 4218046, 4218688, 4216810, ...
# 4                                 [4213694, 4213587]
#
#                                      segment_id_list
# 0  [144212, 144263, 144262, 9014082, 9014081, 140...
# 1  [144212, 144263, 144262, 9014082, 9014081, 140...
# 2  [144212, 144263, 144262, 9014082, 9014081, 140...
# 3  [144212, 144263, 144262, 9014082, 9014081, 140...
# 4  [144212, 144263, 144262, 9014082, 9014081, 140...
#
# [5 rows x 26 columns]

# %%
# change lion geodataframe's index as segment id
gdf_lion_simplified = gdf_lion_simplified.set_index('segment_id')

# %%
# explode 511,lion merged geodataframe. it will create a row for each segment in a list in segment_id_list column
df_511_crash_lion_merged_unstack = df_511_crash.explode('segment_id_list')

# %%
df_511_crash_lion_merged_unstack.head(3)
# Out:
#    event_id    Event Type                          Organizati  \
# 0         0  construction  Port Authority New York/New Jersey
# 0         0  construction  Port Authority New York/New Jersey
# 0         0  construction  Port Authority New York/New Jersey
#
#                  Facility N  Direction       City    County State  \
# 0  George Washington Bridge  Westbound  Manhattan  New York    NY
# 0  George Washington Bridge  Westbound  Manhattan  New York    NY
# 0  George Washington Bridge  Westbound  Manhattan  New York    NY
#
#             Create Tim           Close Time  ...  \
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...
#
#                                       geometry  \
# 0  POINT (-73.9452906062501 40.85016678170324)
# 0  POINT (-73.9452906062501 40.85016678170324)
# 0  POINT (-73.9452906062501 40.85016678170324)
#
#                                buffer_geometry_900ft  \
# 0  POLYGON ((992680.4460278568 251695.5213804595,...
# 0  POLYGON ((992680.4460278568 251695.5213804595,...
# 0  POLYGON ((992680.4460278568 251695.5213804595,...
#
#                               buffer_geometry_1800ft  \
# 0  POLYGON ((993278.5442073554 252368.045084052, ...
# 0  POLYGON ((993278.5442073554 252368.045084052, ...
# 0  POLYGON ((993278.5442073554 252368.045084052, ...
#
#                               buffer_geometry_2700ft  \
# 0  POLYGON ((993495.2826707244 247638.1129178417,...
# 0  POLYGON ((993495.2826707244 247638.1129178417,...
# 0  POLYGON ((993495.2826707244 247638.1129178417,...
#
#                               buffer_geometry_3600ft crash_list_900ft  \
# 0  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
# 0  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
# 0  POLYGON ((993323.9419628344 246752.2208376681,...        [4218698]
#
#              crash_list_1800ft  \
# 0  [4218698, 4220414, 4220401]
# 0  [4218698, 4220414, 4220401]
# 0  [4218698, 4220414, 4220401]
#
#                                    crash_list_2700ft  \
# 0  [4216810, 4218698, 4220414, 4220401, 4218408, ...
# 0  [4216810, 4218698, 4220414, 4220401, 4218408, ...
# 0  [4216810, 4218698, 4220414, 4220401, 4218408, ...
#
#                                    crash_list_3600ft segment_id_list
# 0  [4218684, 4218686, 4218688, 4218046, 4216810, ...          144212
# 0  [4218684, 4218686, 4218688, 4218046, 4216810, ...          144263
# 0  [4218684, 4218686, 4218688, 4218046, 4216810, ...          144262
#
# [3 rows x 26 columns]

# %%
# merge above geodataframe with lion geodataframe based on the segment id
df_511_crash_lion_merged_unstack = df_511_crash_lion_merged_unstack.merge(gdf_lion_simplified, left_on='segment_id_list', right_index=True)

# %%
df_511_crash_lion_merged_unstack.head(3)
# Out:
#    event_id           Event Type                          Organizati  \
# 0         0         construction  Port Authority New York/New Jersey
# 1         1         construction  Port Authority New York/New Jersey
# 2         4  bridge construction  Port Authority New York/New Jersey
#
#                  Facility N  Direction       City    County State  \
# 0  George Washington Bridge  Westbound  Manhattan  New York    NY
# 1  George Washington Bridge  Westbound  Manhattan  New York    NY
# 2  George Washington Bridge  Westbound  Manhattan  New York    NY
#
#             Create Tim           Close Time  ... curve_flag radius  \
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...       None      0
# 1  2019-09-30T23:33:00  2019-10-05T10:01:00  ...       None      0
# 2  2019-09-30T22:35:00  2019-10-04T14:47:00  ...       None      0
#
#    street_width  bike_lane bike_traffic_direction number_travel number_park  \
# 0          30.0       None                   None             2        None
# 1          30.0       None                   None             2        None
# 2          30.0       None                   None             2        None
#
#   number_total posted_speed snow_prior
# 0            2           45          V
# 1            2           45          V
# 2            2           45          V
#
# [3 rows x 40 columns]

# %%
# fill null values as -1
df_511_crash_lion_merged_unstack = df_511_crash_lion_merged_unstack.fillna(-1)

# %%
# drop unnecessary columns
df_511_crash_lion_merged_unstack = df_511_crash_lion_merged_unstack.drop(['segment_id_list'], axis=1)

# %%
df_511_crash_lion_merged_unstack.columns
# Out:
# Index(['event_id', 'Event Type', 'Organizati', 'Facility N', 'Direction',
#        'City', 'County', 'State', 'Create Tim', 'Close Time', 'Event Desc',
#        'Responding', 'Latitude', 'Longitude', 'Duration', 'geometryId',
#        'geometry', 'buffer_geometry_900ft', 'buffer_geometry_1800ft',
#        'buffer_geometry_2700ft', 'buffer_geometry_3600ft', 'crash_list_900ft',
#        'crash_list_1800ft', 'crash_list_2700ft', 'crash_list_3600ft',
#        'segment_type', 'roadway_type', 'traffic_direction', 'loc_status',
#        'curve_flag', 'radius', 'street_width', 'bike_lane',
#        'bike_traffic_direction', 'number_travel', 'number_park',
#        'number_total', 'posted_speed', 'snow_prior'],
#       dtype='object')

# %%
# create the list.
# Here, the element of list are the columns in the 511 dataset (not in lion dataset)
columns = df_511_crash_lion_merged_unstack.columns.tolist()[:25]
columns
# Out:
# ['event_id',
#  'Event Type',
#  'Organizati',
#  'Facility N',
#  'Direction',
#  'City',
#  'County',
#  'State',
#  'Create Tim',
#  'Close Time',
#  'Event Desc',
#  'Responding',
#  'Latitude',
#  'Longitude',
#  'Duration',
#  'geometryId',
#  'geometry',
#  'buffer_geometry_900ft',
#  'buffer_geometry_1800ft',
#  'buffer_geometry_2700ft',
#  'buffer_geometry_3600ft',
#  'crash_list_900ft',
#  'crash_list_1800ft',
#  'crash_list_2700ft',
#  'crash_list_3600ft']

# %%
# groupby columns were in the 511 datasets. we will pick the most frequent value
df_511_crash_lion = df_511_crash_lion_merged_unstack.groupby(columns, as_index=False).agg(lambda x:x.value_counts().index[0])

# %%
df_511_crash_lion.shape
# Out:
# (25358, 39)

# %%
df_511_crash_lion.head(3)
# Out:
#    event_id           Event Type                          Organizati  \
# 0         0         construction  Port Authority New York/New Jersey
# 1         1         construction  Port Authority New York/New Jersey
# 2         2  bridge construction  Port Authority New York/New Jersey
#
#                  Facility N  Direction               City    County State  \
# 0  George Washington Bridge  Westbound          Manhattan  New York    NY
# 1  George Washington Bridge  Westbound          Manhattan  New York    NY
# 2  George Washington Bridge  Westbound  ramp to Manhattan  New York    NY
#
#             Create Tim           Close Time  ... curve_flag radius  \
# 0  2019-09-30T23:45:00  2019-10-06T10:17:00  ...         -1      0
# 1  2019-09-30T23:33:00  2019-10-05T10:01:00  ...         -1      0
# 2  2019-09-30T22:48:00  2019-10-04T14:47:00  ...         -1      0
#
#    street_width  bike_lane bike_traffic_direction number_travel number_park  \
# 0          40.0         -1                     -1             4          -1
# 1          40.0         -1                     -1             4          -1
# 2          35.0         -1                     -1             3          -1
#
#   number_total posted_speed snow_prior
# 0            4           45          V
# 1            4           45          V
# 2            3           50          V
#
# [3 rows x 39 columns]

# %%
df_511_crash_lion.columns
# Out:
# Index(['event_id', 'Event Type', 'Organizati', 'Facility N', 'Direction',
#        'City', 'County', 'State', 'Create Tim', 'Close Time', 'Event Desc',
#        'Responding', 'Latitude', 'Longitude', 'Duration', 'geometryId',
#        'geometry', 'buffer_geometry_900ft', 'buffer_geometry_1800ft',
#        'buffer_geometry_2700ft', 'buffer_geometry_3600ft', 'crash_list_900ft',
#        'crash_list_1800ft', 'crash_list_2700ft', 'crash_list_3600ft',
#        'segment_type', 'roadway_type', 'traffic_direction', 'loc_status',
#        'curve_flag', 'radius', 'street_width', 'bike_lane',
#        'bike_traffic_direction', 'number_travel', 'number_park',
#        'number_total', 'posted_speed', 'snow_prior'],
#       dtype='object')

# %%
df_511_crash_lion.to_csv('../data/cleaned_data/511_crash_lion_0629.csv', index=False)
